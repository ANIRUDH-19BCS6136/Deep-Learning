# %% [markdown]
# # Simple Linear Regression with TensorFlow

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
url = "http://bit.ly/w-data"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
plt.scatter(df["Hours"], df["Scores"])
plt.show()

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(1, input_shape=[1]))
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.SGD(0.02))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(df["Hours"], df["Scores"], epochs=400)
# Out:
# Epoch 1/400
# 1/1 [==============================] - 0s 231ms/step - loss: 2678.4468
# Epoch 2/400
# 1/1 [==============================] - 0s 4ms/step - loss: 239.7897
# Epoch 3/400
# 1/1 [==============================] - 0s 6ms/step - loss: 45.8430
# Epoch 4/400
# 1/1 [==============================] - 0s 4ms/step - loss: 30.4158
# Epoch 5/400
# 1/1 [==============================] - 0s 3ms/step - loss: 29.1861
# Epoch 6/400
# 1/1 [==============================] - 0s 3ms/step - loss: 29.0855
# Epoch 7/400
# 1/1 [==============================] - 0s 5ms/step - loss: 29.0748
# Epoch 8/400
# 1/1 [==============================] - 0s 3ms/step - loss: 29.0713
# Epoch 9/400
# 1/1 [==============================] - 0s 3ms/step - loss: 29.0684
# Epoch 10/400
# 1/1 [==============================] - 0s 3ms/step - loss: 29.0655
# Epoch 11/400
# 1/1 [==============================] - 0s 5ms/step - loss: 29.0627
# Epoch 12/400
# ...

# %%
plt.plot(history.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
df["prediction"] = model.predict(df['Hours'])

# %%
plt.scatter(df["Hours"], df["Scores"])
plt.plot(df["Hours"], df["prediction"], color='r')
plt.show()

# %%
hours = 9.25
test = np.array([hours])
test = test.reshape(-1, 1)
percentage = model.predict(test)
percentage = np.round(percentage, decimals = 1)

print("No of Hours studied per day: {}".format(hours))
print("Predicted Score: {}".format(percentage[0]))
# Out:
# No of Hours studied per day: 9.25
# Predicted Score: [93.]
